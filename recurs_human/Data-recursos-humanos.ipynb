# %%
import pandas as pd
import numpy as np

# %%
drh = pd.read_csv("HRDataset_v14.csv")

# %%
drh.shape #filas y columnas del dataset
# Out:
# (311, 36)

# %%
drh.dtypes #tipos de las variables del dataset
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
drh.head() # visualiza las primeras 5 filas del dataser
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
drh.tail()  # visualiza los ultimos 5 registros del dataset
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 306      Woodson, Jason  10135          0                0         1
# 307  Ybarra, Catherine   10301          0                0         0
# 308    Zamora, Jennifer  10010          0                0         0
# 309         Zhou, Julia  10043          0                0         0
# 310       Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#         ManagerName  ManagerID  RecruitmentSource PerformanceScore  \
# ...

# %%
drh1 = drh[["Employee_Name","Salary","RecruitmentSource","LastPerformanceReview_Date","GenderID","DeptID","PerformanceScore",
            "EmpSatisfaction","EngagementSurvey"]] #filtrado de columnas importantes

# %%
drh1.head(10)
# Out:
#               Employee_Name  Salary   RecruitmentSource  \
# 0       Adinolfi, Wilson  K   62506            LinkedIn
# 1  Ait Sidi, Karthikeyan     104437              Indeed
# 2         Akinkuolie, Sarah   64955            LinkedIn
# 3              Alagbe,Trina   64991              Indeed
# 4          Anderson, Carol    50825       Google Search
# 5         Anderson, Linda     57568            LinkedIn
# 6           Andreola, Colby   95660            LinkedIn
# 7               Athwal, Sam   59365   Employee Referral
# 8          Bachiochi, Linda   47837  Diversity Job Fair
# 9        Bacong, Alejandro    50178              Indeed
#
#   LastPerformanceReview_Date  GenderID  DeptID PerformanceScore  \
# 0                  1/17/2019         1       5          Exceeds
# 1                  2/24/2016         1       3      Fully Meets
# 2                  5/15/2012         0       5      Fully Meets
# 3                   1/3/2019         0       5      Fully Meets
# ...

# %%
drh2=drh1[["Employee_Name","Salary","PerformanceScore","EngagementSurvey"]] #filtadao de 4 columnas

# %%
drh2.head(6)
# Out:
#               Employee_Name  Salary PerformanceScore  EngagementSurvey
# 0       Adinolfi, Wilson  K   62506          Exceeds              4.60
# 1  Ait Sidi, Karthikeyan     104437      Fully Meets              4.96
# 2         Akinkuolie, Sarah   64955      Fully Meets              3.02
# 3              Alagbe,Trina   64991      Fully Meets              4.84
# 4          Anderson, Carol    50825      Fully Meets              5.00
# 5         Anderson, Linda     57568          Exceeds              5.00

# %%
drh3 = drh1[["Employee_Name","Salary","PerformanceScore","EngagementSurvey"]]  #filtadao de 4 columnas con rando de filas

# %%
drh3 = drh3.iloc[7:12]

# %%
drh3
# Out:
#            Employee_Name  Salary PerformanceScore  EngagementSurvey
# 7            Athwal, Sam   59365      Fully Meets              5.00
# 8       Bachiochi, Linda   47837      Fully Meets              4.46
# 9     Bacong, Alejandro    50178      Fully Meets              5.00
# 10  Baczenski, Rachael     54670      Fully Meets              4.20
# 11       Barbara, Thomas   47211      Fully Meets              4.20

# %%
pd.concat([drh2,drh3]) # concatenamos tablas con mismo N de columnas
# Out:
#                Employee_Name  Salary PerformanceScore  EngagementSurvey
# 0        Adinolfi, Wilson  K   62506          Exceeds              4.60
# 1   Ait Sidi, Karthikeyan     104437      Fully Meets              4.96
# 2          Akinkuolie, Sarah   64955      Fully Meets              3.02
# 3               Alagbe,Trina   64991      Fully Meets              4.84
# 4           Anderson, Carol    50825      Fully Meets              5.00
# ..                       ...     ...              ...               ...
# 7                Athwal, Sam   59365      Fully Meets              5.00
# 8           Bachiochi, Linda   47837      Fully Meets              4.46
# 9         Bacong, Alejandro    50178      Fully Meets              5.00
# 10      Baczenski, Rachael     54670      Fully Meets              4.20
# 11           Barbara, Thomas   47211      Fully Meets              4.20
#
# [316 rows x 4 columns]

# %%
drh4 = pd.concat([drh2,drh3])

# %%
drh5=drh4[["Employee_Name"]]

# %%
drh6 =drh4[["Salary","PerformanceScore","EngagementSurvey"]]

# %%
drh5
# Out:
#                Employee_Name
# 0        Adinolfi, Wilson  K
# 1   Ait Sidi, Karthikeyan
# 2          Akinkuolie, Sarah
# 3               Alagbe,Trina
# 4           Anderson, Carol
# ..                       ...
# 7                Athwal, Sam
# 8           Bachiochi, Linda
# 9         Bacong, Alejandro
# 10      Baczenski, Rachael
# 11           Barbara, Thomas
#
# [316 rows x 1 columns]

# %%
drh6
# Out:
#     Salary PerformanceScore  EngagementSurvey
# 0    62506          Exceeds              4.60
# 1   104437      Fully Meets              4.96
# 2    64955      Fully Meets              3.02
# 3    64991      Fully Meets              4.84
# 4    50825      Fully Meets              5.00
# ..     ...              ...               ...
# 7    59365      Fully Meets              5.00
# 8    47837      Fully Meets              4.46
# 9    50178      Fully Meets              5.00
# 10   54670      Fully Meets              4.20
# 11   47211      Fully Meets              4.20
#
# [316 rows x 3 columns]

# %%
pd.concat([drh5,drh6], axis = 1)  # concatenamos tablas con diferente N de columnas
# Out:
#                Employee_Name  Salary PerformanceScore  EngagementSurvey
# 0        Adinolfi, Wilson  K   62506          Exceeds              4.60
# 1   Ait Sidi, Karthikeyan     104437      Fully Meets              4.96
# 2          Akinkuolie, Sarah   64955      Fully Meets              3.02
# 3               Alagbe,Trina   64991      Fully Meets              4.84
# 4           Anderson, Carol    50825      Fully Meets              5.00
# ..                       ...     ...              ...               ...
# 7                Athwal, Sam   59365      Fully Meets              5.00
# 8           Bachiochi, Linda   47837      Fully Meets              4.46
# 9         Bacong, Alejandro    50178      Fully Meets              5.00
# 10      Baczenski, Rachael     54670      Fully Meets              4.20
# 11           Barbara, Thomas   47211      Fully Meets              4.20
#
# [316 rows x 4 columns]

# %%
drh2.head()
# Out:
#               Employee_Name  Salary PerformanceScore  EngagementSurvey
# 0       Adinolfi, Wilson  K   62506          Exceeds              4.60
# 1  Ait Sidi, Karthikeyan     104437      Fully Meets              4.96
# 2         Akinkuolie, Sarah   64955      Fully Meets              3.02
# 3              Alagbe,Trina   64991      Fully Meets              4.84
# 4          Anderson, Carol    50825      Fully Meets              5.00

# %%
drh2.sort_values("EngagementSurvey").head() # ordenamos columnas seleccionada de forma ascendente
# Out:
#            Employee_Name  Salary PerformanceScore  EngagementSurvey
# 69       Desimone, Carl    53189              PIP              1.12
# 91            Fett, Boba   53366              PIP              1.20
# 90   Fernandes, Nilson     64057              PIP              1.56
# 267   Stansfield, Norman   58273              PIP              1.81
# 67         Delarge, Alex   61568              PIP              1.93

# %%
drh2.sort_values("EngagementSurvey", ascending = False).head() # ordenamos columnas seleccionada de forma descendente
# Out:
#          Employee_Name  Salary PerformanceScore  EngagementSurvey
# 206    Oliver, Brooke    71966      Fully Meets               5.0
# 212   Patronick, Lucas  108987          Exceeds               5.0
# 202     Nguyen, Dheepa   63695      Fully Meets               5.0
# 59         Cross, Noah   92329      Fully Meets               5.0
# 97   Foster-Baker, Amy   99351      Fully Meets               5.0

# %%
salr = drh2[drh2["Salary"] > 100000]  # ordenamos columnas con los salarios mayor a 100000
print(salr.shape)
# Out:
# (25, 4)

# %%
salr.head()
# Out:
#                Employee_Name  Salary PerformanceScore  EngagementSurvey
# 1   Ait Sidi, Karthikeyan     104437      Fully Meets              4.96
# 18             Becker, Renee  110000      Fully Meets              4.50
# 25              Booth, Frank  103613      Fully Meets              3.50
# 26         Boutwell, Bonalyn  106367      Fully Meets              5.00
# 39          Carr, Claudia  N  100031      Fully Meets              5.00

# %%
salr.sort_values("EngagementSurvey", ascending = False).head()
# Out:
#                 Employee_Name  Salary PerformanceScore  EngagementSurvey
# 96                Foss, Jason  178000          Exceeds              5.00
# 26          Boutwell, Bonalyn  106367      Fully Meets              5.00
# 39           Carr, Claudia  N  100031      Fully Meets              5.00
# 212          Patronick, Lucas  108987          Exceeds              5.00
# 1    Ait Sidi, Karthikeyan     104437      Fully Meets              4.96

# %%
salr.rename(columns ={"PerformanceScore":"Score"}).head() #cambiamos nombre de columna
# Out:
#                Employee_Name  Salary        Score  EngagementSurvey
# 1   Ait Sidi, Karthikeyan     104437  Fully Meets              4.96
# 18             Becker, Renee  110000  Fully Meets              4.50
# 25              Booth, Frank  103613  Fully Meets              3.50
# 26         Boutwell, Bonalyn  106367  Fully Meets              5.00
# 39          Carr, Claudia  N  100031  Fully Meets              5.00

# %%
drh
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
drh.shape
# Out:
# (311, 36)

# %%
# eliminar columnas
drh_drop = drh.drop(columns=["FromDiversityJobFairID","SpecialProjectsCount","DaysLateLast30"])
drh_drop
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  Salary  Termd  ...  \
# ...

# %%
drh_drop.shape
# Out:
# (311, 33)

# %%
drh1.sample(5)
# Out:
#              Employee_Name  Salary   RecruitmentSource  \
# 29              Brown, Mia   63000  Diversity Job Fair
# 108          Goble, Taisha  114800              Indeed
# 26       Boutwell, Bonalyn  106367  Diversity Job Fair
# 199            Ndzi, Horia   46664   Employee Referral
# 246  Saar-Beckles, Melinda   47750  Diversity Job Fair
#
#     LastPerformanceReview_Date  GenderID  DeptID   PerformanceScore  \
# 29                   1/15/2019         0       1        Fully Meets
# 108                  1/20/2015         0       3        Fully Meets
# 26                   2/18/2019         0       1        Fully Meets
# 199                   3/6/2016         1       5        Fully Meets
# 246                  2/18/2019         0       5  Needs Improvement
#
#      EmpSatisfaction  EngagementSurvey
# 29                 2              4.50
# 108                4              4.60
# 26                 4              5.00
# 199                3              3.18
# ...

# %%
#filtra de columnas
drh1_filt= drh1[drh1.Salary>100000]
drh1_filt
# Out:
#                 Employee_Name  Salary   RecruitmentSource  \
# 1    Ait Sidi, Karthikeyan     104437              Indeed
# 18              Becker, Renee  110000       Google Search
# 25               Booth, Frank  103613            LinkedIn
# 26          Boutwell, Bonalyn  106367  Diversity Job Fair
# 39           Carr, Claudia  N  100031            LinkedIn
# 42          Champaigne, Brian  110929              Indeed
# 55             Corleone, Vito  170500              Indeed
# 66          Del Bosque, Keyla  101199       CareerBuilder
# 76              Dougall, Eric  138888              Indeed
# 96                Foss, Jason  178000              Indeed
# 108             Goble, Taisha  114800              Indeed
# 131           Houlihan, Debra  180000            LinkedIn
# 144          Johnson, Noelle   105700              Indeed
# 150               King, Janet  250000              Indeed
# 180            Martin, Sandra  105688       Google Search
# ...

# %%
drh1_filt.shape
# Out:
# (25, 9)

# %%
drh1_filt= drh1[drh1.EngagementSurvey<3]
drh1_filt
# Out:
#              Employee_Name  Salary   RecruitmentSource  \
# 23          Blount, Dianna   66441       CareerBuilder
# 53           Cole, Spencer   59144            LinkedIn
# 67           Delarge, Alex   61568              Indeed
# 69         Desimone, Carl    53189              Indeed
# 72       Dietrich, Jenna     59231             Website
# 79              Dunne, Amy   62514       Google Search
# 85          Evensen, April   59124       Google Search
# 86          Exantus, Susan   99280              Indeed
# 90     Fernandes, Nilson     64057              Indeed
# 91              Fett, Boba   53366            LinkedIn
# 95           Forrest, Alex   70187   Employee Referral
# 137      Immediato, Walter   83082              Indeed
# 190          Monroe, Peter  157000  Diversity Job Fair
# 205           O'hare, Lynn   52674            LinkedIn
# 215      Pelletier, Ermine   60270       CareerBuilder
# 246  Saar-Beckles, Melinda   47750  Diversity Job Fair
# ...

# %%
drh1.shape
# Out:
# (311, 9)

# %%
frac=drh1.sample(frac=0.1) # filtra el 10 % de las filas
frac.shape
# Out:
# (31, 9)
